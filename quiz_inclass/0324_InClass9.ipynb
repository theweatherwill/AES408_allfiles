# %%
import shapely
class home:
    """
    Attributes
    ----------
    """

    def __init__(self, address, latitude, longitude, resident):
        self.address = address
        self.coords = shapely.Point(latitude, longitude)
        self.resident = list[residents]

    def get_contact_info(self):
        return self.resident

# %%
class person:
    """
    Attributes
    ----------
    """

    def __init__(self, name, phone_number):
        self.name = name
        self.phone_number = phone_number

# %%
residents = []

# %%
resident1 = residents.append(person("Bob", 1234567890))

# %%
resident2 = residents.append(person("Sue", 2345678901))

# %%
house = home("12 Road", 30, -85, residents)

# %%
house

# %%
print(house.get_contact_info())
# Out:
# list[[<__main__.person object at 0x0000021702FF3620>, <__main__.person object at 0x00000217049A1950>]]
