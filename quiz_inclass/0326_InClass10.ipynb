# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

penguins = pd.read_csv(r"C:\Users\wdonalds\Documents\AES408_notes_inclass_files\penguins.csv")

# %%
sns.displot(
    penguins, x="bill_length_mm",
    binwidth=3, height=3, facet_kws=dict(margin_titles=True),
)

# %%
plt.hist(penguins["bill_length_mm"])
plt.show()

# %%
import plotly.express as px

fig = px.histogram(penguins, x="bill_length_mm")
fig.show()

# %%
sns.histplot(data=penguins, x="bill_length_mm", hue="island", multiple="stack")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='Count'>
